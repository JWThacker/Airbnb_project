# %%
import json

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('feat_types_merged_calendar_listings.json', 'r') as f:
    feat_types = json.load(f)

# %%
df = pd.read_csv('calendar_listings.csv', dtype=feat_types, parse_dates=['host_since'])

# %%
df.sample(5)
# Out:
#             id                                               name  \
# 36    10116095                       Comfortable & Clean - Boston
# 819   14414473  Modern living in a conveniently located browns...
# 2351  11788394  Luxury brownstone close to Fenway with river v...
# 2446   8439372                   Brand New Apt in Great Location!
# 1180   8309604                Back Bay / South End - best of both
#
#                                                 summary  \
# 36    Comfortable private room with a queen sized be...
# 819   750 sq ft of recently renovated contemporary l...
# 2351  Luxury condo in a gut renovated brownstone ste...
# 2446  Just updated apartment in the best location. W...
# 1180  This location is the absolute heart of the cit...
#
#                                             description experiences_offered  \
# 36    Comfortable private room with a queen sized be...                none
# 819   750 sq ft of recently renovated contemporary l...                none
# 2351  Luxury condo in a gut renovated brownstone ste...                none
# 2446  Just updated apartment in the best location. W...                none
# 1180  This location is the absolute heart of the cit...                none
#
#      host_since                                host_location  \
# 36   2011-09-30         Boston, Massachusetts, United States
# 819  2013-03-27  North Andover, Massachusetts, United States
# 2351 2015-02-02         Boston, Massachusetts, United States
# 2446 2015-09-16         Boston, Massachusetts, United States
# 1180 2012-11-12         Boston, Massachusetts, United States
#
#      host_response_time  host_response_rate  host_acceptance_rate  ...  \
# 36                  1-3               100.0                 100.0  ...
# 819                 0-1               100.0                 100.0  ...
# 2351               3-24                80.0                  67.0  ...
# 2446                1-3               100.0                 100.0  ...
# 1180               3-24                50.0                  50.0  ...
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 36                           False                            False
# 819                          False                            False
# 2351                         False                            False
# 2446                         False                            False
# 1180                         False                            False
#
#       calculated_host_listings_count  reviews_per_month number_of_NAs  \
# 36                                 1                NaN            26
# 819                                1                4.0             8
# 2351                               1               1.41            11
# 2446                               1               2.74             5
# 1180                               2               0.09            12
#
#      listing_id  mean_price stand_dev_price median_price    city
# 36     10116095  116.116809        1.796990        115.0  Boston
# 819    14414473  146.938776        8.209064        150.0  Boston
# 2351   11788394  228.051948        9.464471        220.0  Boston
# 2446    8439372  295.000000        0.000000        295.0  Boston
# 1180        NaN         NaN             NaN          NaN  Boston
#
# [5 rows x 67 columns]
